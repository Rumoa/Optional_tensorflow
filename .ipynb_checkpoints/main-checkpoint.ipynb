# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("krkopt.data", header=None)

# %%
data.columns = ["wkc", "wkr", "wrc", "wrr", "bkc", "bkr", "opt rank" ]

# %%
data
# Out:
#       wkc  wkr wrc  wrr bkc  bkr opt rank
# 0       a    1   b    3   c    2     draw
# 1       a    1   c    1   c    2     draw
# 2       a    1   c    1   d    1     draw
# 3       a    1   c    1   d    2     draw
# 4       a    1   c    2   c    1     draw
# ...    ..  ...  ..  ...  ..  ...      ...
# 28051   b    1   g    7   e    5  sixteen
# 28052   b    1   g    7   e    6  sixteen
# 28053   b    1   g    7   e    7  sixteen
# 28054   b    1   g    7   f    5  sixteen
# 28055   b    1   g    7   g    5  sixteen
#
# [28056 rows x 7 columns]

# %%
X = data.iloc[:, 0:6]
y = data['opt rank']

# %%
X
# Out:
#       wkc  wkr wrc  wrr bkc  bkr
# 0       a    1   b    3   c    2
# 1       a    1   c    1   c    2
# 2       a    1   c    1   d    1
# 3       a    1   c    1   d    2
# 4       a    1   c    2   c    1
# ...    ..  ...  ..  ...  ..  ...
# 28051   b    1   g    7   e    5
# 28052   b    1   g    7   e    6
# 28053   b    1   g    7   e    7
# 28054   b    1   g    7   f    5
# 28055   b    1   g    7   g    5
#
# [28056 rows x 6 columns]

# %%
X["wkc"]=X["wkc"].astype('category')
X["wrc"]=X["wrc"].astype('category')
X["bkc"]=X["bkc"].astype('category')

# %%
X["wkc"]=X["wkc"].cat.codes
X["wrc"]=X["wrc"].cat.codes
X["bkc"]=X["bkc"].cat.codes

# %%
X
# Out:
#        wkc  wkr  wrc  wrr  bkc  bkr
# 0        0    1    1    3    2    2
# 1        0    1    2    1    2    2
# 2        0    1    2    1    3    1
# 3        0    1    2    1    3    2
# 4        0    1    2    2    2    1
# ...    ...  ...  ...  ...  ...  ...
# 28051    1    1    6    7    4    5
# 28052    1    1    6    7    4    6
# 28053    1    1    6    7    4    7
# 28054    1    1    6    7    5    5
# 28055    1    1    6    7    6    5
#
# [28056 rows x 6 columns]

# %%
y = y.astype('category')
y = y.cat.codes

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split

# %%
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                   y, test_size=0.2,
                                                   random_state = 1)

from imblearn.over_sampling import SMOTE
oversample = SMOTE()


X_smote, y_smote = oversample.fit_resample(X, y)

X_train_smote, X_test_smote, y_train_smote, y_test_smote = train_test_split(X_smote,
                                                   y_smote, test_size=0.2,
                                                   random_state = 1)



y_train = to_categorical(y_train)
y_test  = to_categorical(y_test)
y_train_smote = to_categorical(y_train_smote)
y_test_smote = to_categorical(y_test_smote)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

scaler = StandardScaler().fit(X_train_smote)
X_train_smote = scaler.transform(X_train_smote)
X_test_smote = scaler.transform(X_test_smote)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


checkpoint_filepath = '/tmp/checkpoint'

# %%
def make_my_model_multi( units_per_layer, input_s, output_s, activation_='relu'):
    model = Sequential()
    depth = len(units_per_layer)
    model.add(Dense(units_per_layer[0], activation=activation_, input_shape=(input_s,)))
    for i in range(1, depth):
        model.add(Dense(units_per_layer[i], activation=activation_))
    model.add(Dense(output_s, activation = 'softmax'))   
    
    return model




#En este caso, usamos categorical_crossentropy como función de coste y 
#permitimos elegir otro batch para poder hacer uso de 
def compile_fit_multiclass(modelo, X_train, X_test, y_train, batch, epochs, verbose=0):
    modelo.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
    
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=True)

    model_checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,
                                                        save_weights_only=True,
                                                        monitor='val_loss',
                                                        mode='min',
                                                        save_best_only=True,
                                                        verbose=True)

    modelo.fit(X_train, y_train, epochs=epochs, batch_size=batch, verbose=verbose, validation_split=0.2, callbacks = [early_stopping, model_checkpoint])
    #model.load_weights(checkpoint_filepath)
    predictions = modelo.predict(X_test)
    return predictions

def compute_metrics_multiclass(y_test, y_pred):
    results=[]
    results.append(precision_score(y_test, np.round(y_pred), average="micro"))
    results.append(recall_score(y_test, np.round(y_pred), average="micro"))
    results.append(f1_score(y_test, np.round(y_pred), average="micro"))
    results.append(cohen_kappa_score(y_test, np.round(y_pred)))
    return results

# %%
y.shape
# Out:
# (28056,)

# %%
model = make_my_model_multi([100, 100, 100, 100], 6, 18, activation_='relu' )
compile_fit_multiclass(model, X_train, X_test, y_train, 256, 200, verbose=1)
# Out:
# Epoch 1/200
# 71/71 [==============================] - 1s 6ms/step - loss: 2.5107 - accuracy: 0.1790 - val_loss: 1.8741 - val_accuracy: 0.3237
#
# Epoch 00001: val_loss improved from inf to 1.87412, saving model to /tmp/checkpoint
# Epoch 2/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.7756 - accuracy: 0.3512 - val_loss: 1.5505 - val_accuracy: 0.4239
#
# Epoch 00002: val_loss improved from 1.87412 to 1.55048, saving model to /tmp/checkpoint
# Epoch 3/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.5242 - accuracy: 0.4274 - val_loss: 1.4306 - val_accuracy: 0.4531
#
# Epoch 00003: val_loss improved from 1.55048 to 1.43060, saving model to /tmp/checkpoint
# Epoch 4/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.4020 - accuracy: 0.4714 - val_loss: 1.3532 - val_accuracy: 0.4685
#
# Epoch 00004: val_loss improved from 1.43060 to 1.35324, saving model to /tmp/checkpoint
# Epoch 5/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.3196 - accuracy: 0.4903 - val_loss: 1.2755 - val_accuracy: 0.5041
#
# Epoch 00005: val_loss improved from 1.35324 to 1.27553, saving model to /tmp/checkpoint
# Epoch 6/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.2624 - accuracy: 0.5057 - val_loss: 1.2147 - val_accuracy: 0.5190
#
# Epoch 00006: val_loss improved from 1.27553 to 1.21469, saving model to /tmp/checkpoint
# Epoch 7/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.2171 - accuracy: 0.5206 - val_loss: 1.1923 - val_accuracy: 0.5275
#
# Epoch 00007: val_loss improved from 1.21469 to 1.19228, saving model to /tmp/checkpoint
# Epoch 8/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.1772 - accuracy: 0.5296 - val_loss: 1.1499 - val_accuracy: 0.5431
#
# Epoch 00008: val_loss improved from 1.19228 to 1.14993, saving model to /tmp/checkpoint
# Epoch 9/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.1430 - accuracy: 0.5457 - val_loss: 1.1514 - val_accuracy: 0.5420
#
# Epoch 00009: val_loss did not improve from 1.14993
# Epoch 10/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.1306 - accuracy: 0.5460 - val_loss: 1.1108 - val_accuracy: 0.5482
#
# Epoch 00010: val_loss improved from 1.14993 to 1.11084, saving model to /tmp/checkpoint
# Epoch 11/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.0980 - accuracy: 0.5540 - val_loss: 1.0794 - val_accuracy: 0.5554
#
# Epoch 00011: val_loss improved from 1.11084 to 1.07936, saving model to /tmp/checkpoint
# Epoch 12/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.0675 - accuracy: 0.5618 - val_loss: 1.1123 - val_accuracy: 0.5400
#
# Epoch 00012: val_loss did not improve from 1.07936
# Epoch 13/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.0370 - accuracy: 0.5813 - val_loss: 1.0490 - val_accuracy: 0.5710
#
# Epoch 00013: val_loss improved from 1.07936 to 1.04904, saving model to /tmp/checkpoint
# Epoch 14/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.0168 - accuracy: 0.5825 - val_loss: 1.0106 - val_accuracy: 0.5819
#
# Epoch 00014: val_loss improved from 1.04904 to 1.01059, saving model to /tmp/checkpoint
# Epoch 15/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.9993 - accuracy: 0.5944 - val_loss: 1.0099 - val_accuracy: 0.5781
#
# Epoch 00015: val_loss improved from 1.01059 to 1.00991, saving model to /tmp/checkpoint
# Epoch 16/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.9753 - accuracy: 0.5943 - val_loss: 0.9669 - val_accuracy: 0.6050
#
# Epoch 00016: val_loss improved from 1.00991 to 0.96685, saving model to /tmp/checkpoint
# Epoch 17/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.9615 - accuracy: 0.6093 - val_loss: 0.9724 - val_accuracy: 0.6026
#
# Epoch 00017: val_loss did not improve from 0.96685
# Epoch 18/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.9377 - accuracy: 0.6164 - val_loss: 0.9401 - val_accuracy: 0.6099
#
# Epoch 00018: val_loss improved from 0.96685 to 0.94014, saving model to /tmp/checkpoint
# Epoch 19/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.9062 - accuracy: 0.6338 - val_loss: 0.9218 - val_accuracy: 0.6146
#
# Epoch 00019: val_loss improved from 0.94014 to 0.92179, saving model to /tmp/checkpoint
# Epoch 20/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.8861 - accuracy: 0.6336 - val_loss: 0.9094 - val_accuracy: 0.6258
#
# Epoch 00020: val_loss improved from 0.92179 to 0.90937, saving model to /tmp/checkpoint
# Epoch 21/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.8844 - accuracy: 0.6387 - val_loss: 0.9065 - val_accuracy: 0.6202
#
# Epoch 00021: val_loss improved from 0.90937 to 0.90646, saving model to /tmp/checkpoint
# Epoch 22/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.8824 - accuracy: 0.6384 - val_loss: 0.8837 - val_accuracy: 0.6364
#
# Epoch 00022: val_loss improved from 0.90646 to 0.88366, saving model to /tmp/checkpoint
# Epoch 23/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.8377 - accuracy: 0.6562 - val_loss: 0.8536 - val_accuracy: 0.6558
#
# Epoch 00023: val_loss improved from 0.88366 to 0.85359, saving model to /tmp/checkpoint
# Epoch 24/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.8270 - accuracy: 0.6574 - val_loss: 0.8617 - val_accuracy: 0.6389
#
# Epoch 00024: val_loss did not improve from 0.85359
# Epoch 25/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.8212 - accuracy: 0.6653 - val_loss: 0.8699 - val_accuracy: 0.6384
#
# Epoch 00025: val_loss did not improve from 0.85359
# Epoch 26/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.8196 - accuracy: 0.6593 - val_loss: 0.8329 - val_accuracy: 0.6589
#
# Epoch 00026: val_loss improved from 0.85359 to 0.83292, saving model to /tmp/checkpoint
# Epoch 27/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7896 - accuracy: 0.6721 - val_loss: 0.8176 - val_accuracy: 0.6750
#
# Epoch 00027: val_loss improved from 0.83292 to 0.81759, saving model to /tmp/checkpoint
# Epoch 28/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.7764 - accuracy: 0.6818 - val_loss: 0.8756 - val_accuracy: 0.6413
#
# Epoch 00028: val_loss did not improve from 0.81759
# Epoch 29/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7804 - accuracy: 0.6777 - val_loss: 0.8112 - val_accuracy: 0.6725
#
# Epoch 00029: val_loss improved from 0.81759 to 0.81122, saving model to /tmp/checkpoint
# Epoch 30/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.7599 - accuracy: 0.6869 - val_loss: 0.8013 - val_accuracy: 0.6721
#
# Epoch 00030: val_loss improved from 0.81122 to 0.80125, saving model to /tmp/checkpoint
# Epoch 31/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7425 - accuracy: 0.6931 - val_loss: 0.8117 - val_accuracy: 0.6632
#
# Epoch 00031: val_loss did not improve from 0.80125
# Epoch 32/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7585 - accuracy: 0.6921 - val_loss: 0.8087 - val_accuracy: 0.6643
#
# Epoch 00032: val_loss did not improve from 0.80125
# Epoch 33/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.7345 - accuracy: 0.6985 - val_loss: 0.7778 - val_accuracy: 0.6843
#
# Epoch 00033: val_loss improved from 0.80125 to 0.77781, saving model to /tmp/checkpoint
# Epoch 34/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7185 - accuracy: 0.7030 - val_loss: 0.7418 - val_accuracy: 0.7031
#
# Epoch 00034: val_loss improved from 0.77781 to 0.74179, saving model to /tmp/checkpoint
# Epoch 35/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6834 - accuracy: 0.7219 - val_loss: 0.7420 - val_accuracy: 0.7066
#
# Epoch 00035: val_loss did not improve from 0.74179
# Epoch 36/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6994 - accuracy: 0.7109 - val_loss: 0.7932 - val_accuracy: 0.6714
#
# Epoch 00036: val_loss did not improve from 0.74179
# Epoch 37/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6919 - accuracy: 0.7146 - val_loss: 0.7448 - val_accuracy: 0.6921
#
# Epoch 00037: val_loss did not improve from 0.74179
# Epoch 38/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6673 - accuracy: 0.7229 - val_loss: 0.7273 - val_accuracy: 0.7037
#
# Epoch 00038: val_loss improved from 0.74179 to 0.72729, saving model to /tmp/checkpoint
# Epoch 39/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6567 - accuracy: 0.7299 - val_loss: 0.7059 - val_accuracy: 0.7126
#
# Epoch 00039: val_loss improved from 0.72729 to 0.70593, saving model to /tmp/checkpoint
# Epoch 40/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.6447 - accuracy: 0.7407 - val_loss: 0.7218 - val_accuracy: 0.7144
#
# Epoch 00040: val_loss did not improve from 0.70593
# Epoch 41/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6432 - accuracy: 0.7363 - val_loss: 0.7166 - val_accuracy: 0.7048
#
# Epoch 00041: val_loss did not improve from 0.70593
# Epoch 42/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6476 - accuracy: 0.7310 - val_loss: 0.7130 - val_accuracy: 0.7100
#
# Epoch 00042: val_loss did not improve from 0.70593
# Epoch 43/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.6233 - accuracy: 0.7465 - val_loss: 0.7371 - val_accuracy: 0.6977
#
# Epoch 00043: val_loss did not improve from 0.70593
# Epoch 44/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6459 - accuracy: 0.7350 - val_loss: 0.7076 - val_accuracy: 0.7137
#
# Epoch 00044: val_loss did not improve from 0.70593
# Epoch 45/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6165 - accuracy: 0.7544 - val_loss: 0.6999 - val_accuracy: 0.7137
#
# Epoch 00045: val_loss improved from 0.70593 to 0.69991, saving model to /tmp/checkpoint
# Epoch 46/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6045 - accuracy: 0.7559 - val_loss: 0.6742 - val_accuracy: 0.7235
#
# Epoch 00046: val_loss improved from 0.69991 to 0.67418, saving model to /tmp/checkpoint
# Epoch 47/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.6205 - accuracy: 0.7477 - val_loss: 0.6739 - val_accuracy: 0.7347
#
# Epoch 00047: val_loss improved from 0.67418 to 0.67392, saving model to /tmp/checkpoint
# Epoch 48/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5943 - accuracy: 0.7541 - val_loss: 0.6783 - val_accuracy: 0.7276
#
# Epoch 00048: val_loss did not improve from 0.67392
# Epoch 49/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5856 - accuracy: 0.7584 - val_loss: 0.6888 - val_accuracy: 0.7198
#
# Epoch 00049: val_loss did not improve from 0.67392
# Epoch 50/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5895 - accuracy: 0.7568 - val_loss: 0.6909 - val_accuracy: 0.7200
#
# Epoch 00050: val_loss did not improve from 0.67392
# Epoch 51/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5782 - accuracy: 0.7631 - val_loss: 0.6654 - val_accuracy: 0.7354
#
# Epoch 00051: val_loss improved from 0.67392 to 0.66544, saving model to /tmp/checkpoint
# Epoch 52/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5800 - accuracy: 0.7647 - val_loss: 0.6814 - val_accuracy: 0.7222
#
# Epoch 00052: val_loss did not improve from 0.66544
# Epoch 53/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5611 - accuracy: 0.7760 - val_loss: 0.6838 - val_accuracy: 0.7224
#
# Epoch 00053: val_loss did not improve from 0.66544
# Epoch 54/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5665 - accuracy: 0.7650 - val_loss: 0.6538 - val_accuracy: 0.7342
#
# Epoch 00054: val_loss improved from 0.66544 to 0.65379, saving model to /tmp/checkpoint
# Epoch 55/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.5495 - accuracy: 0.7768 - val_loss: 0.6270 - val_accuracy: 0.7434
#
# Epoch 00055: val_loss improved from 0.65379 to 0.62702, saving model to /tmp/checkpoint
# Epoch 56/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5392 - accuracy: 0.7795 - val_loss: 0.7238 - val_accuracy: 0.7064
#
# Epoch 00056: val_loss did not improve from 0.62702
# Epoch 57/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5570 - accuracy: 0.7755 - val_loss: 0.6323 - val_accuracy: 0.7481
#
# Epoch 00057: val_loss did not improve from 0.62702
# Epoch 58/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5702 - accuracy: 0.7631 - val_loss: 0.6228 - val_accuracy: 0.7496
#
# Epoch 00058: val_loss improved from 0.62702 to 0.62283, saving model to /tmp/checkpoint
# Epoch 59/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5343 - accuracy: 0.7779 - val_loss: 0.6137 - val_accuracy: 0.7579
#
# Epoch 00059: val_loss improved from 0.62283 to 0.61367, saving model to /tmp/checkpoint
# Epoch 60/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.5214 - accuracy: 0.7879 - val_loss: 0.6256 - val_accuracy: 0.7420
#
# Epoch 00060: val_loss did not improve from 0.61367
# Epoch 61/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5078 - accuracy: 0.7990 - val_loss: 0.6311 - val_accuracy: 0.7476
#
# Epoch 00061: val_loss did not improve from 0.61367
# Epoch 62/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5208 - accuracy: 0.7903 - val_loss: 0.6163 - val_accuracy: 0.7514
#
# Epoch 00062: val_loss did not improve from 0.61367
# Epoch 63/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5102 - accuracy: 0.7923 - val_loss: 0.6097 - val_accuracy: 0.7545
#
# Epoch 00063: val_loss improved from 0.61367 to 0.60973, saving model to /tmp/checkpoint
# Epoch 64/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5218 - accuracy: 0.7873 - val_loss: 0.6165 - val_accuracy: 0.7521
#
# Epoch 00064: val_loss did not improve from 0.60973
# Epoch 65/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4999 - accuracy: 0.7970 - val_loss: 0.6611 - val_accuracy: 0.7354
#
# Epoch 00065: val_loss did not improve from 0.60973
# Epoch 66/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4999 - accuracy: 0.7986 - val_loss: 0.6000 - val_accuracy: 0.7628
#
# Epoch 00066: val_loss improved from 0.60973 to 0.59999, saving model to /tmp/checkpoint
# Epoch 67/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4972 - accuracy: 0.7976 - val_loss: 0.6215 - val_accuracy: 0.7516
#
# Epoch 00067: val_loss did not improve from 0.59999
# Epoch 68/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5037 - accuracy: 0.7946 - val_loss: 0.6221 - val_accuracy: 0.7536
#
# Epoch 00068: val_loss did not improve from 0.59999
# Epoch 69/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4897 - accuracy: 0.7986 - val_loss: 0.6134 - val_accuracy: 0.7561
#
# Epoch 00069: val_loss did not improve from 0.59999
# Epoch 70/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4977 - accuracy: 0.7969 - val_loss: 0.6127 - val_accuracy: 0.7574
#
# Epoch 00070: val_loss did not improve from 0.59999
# Epoch 71/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4807 - accuracy: 0.8058 - val_loss: 0.6166 - val_accuracy: 0.7521
#
# Epoch 00071: val_loss did not improve from 0.59999
# Epoch 72/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4770 - accuracy: 0.8078 - val_loss: 0.5984 - val_accuracy: 0.7607
#
# Epoch 00072: val_loss improved from 0.59999 to 0.59839, saving model to /tmp/checkpoint
# Epoch 73/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4744 - accuracy: 0.8098 - val_loss: 0.6004 - val_accuracy: 0.7554
#
# Epoch 00073: val_loss did not improve from 0.59839
# Epoch 74/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4750 - accuracy: 0.8079 - val_loss: 0.6111 - val_accuracy: 0.7636
#
# Epoch 00074: val_loss did not improve from 0.59839
# Epoch 75/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4611 - accuracy: 0.8156 - val_loss: 0.6158 - val_accuracy: 0.7570
#
# Epoch 00075: val_loss did not improve from 0.59839
# Epoch 76/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4602 - accuracy: 0.8168 - val_loss: 0.5678 - val_accuracy: 0.7786
#
# Epoch 00076: val_loss improved from 0.59839 to 0.56780, saving model to /tmp/checkpoint
# Epoch 77/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4450 - accuracy: 0.8248 - val_loss: 0.6071 - val_accuracy: 0.7601
#
# Epoch 00077: val_loss did not improve from 0.56780
# Epoch 78/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4574 - accuracy: 0.8150 - val_loss: 0.6156 - val_accuracy: 0.7570
#
# Epoch 00078: val_loss did not improve from 0.56780
# Epoch 79/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4454 - accuracy: 0.8222 - val_loss: 0.5938 - val_accuracy: 0.7668
#
# Epoch 00079: val_loss did not improve from 0.56780
# Epoch 80/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4488 - accuracy: 0.8236 - val_loss: 0.5885 - val_accuracy: 0.7661
#
# Epoch 00080: val_loss did not improve from 0.56780
# Epoch 81/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4430 - accuracy: 0.8213 - val_loss: 0.6043 - val_accuracy: 0.7656
#
# Epoch 00081: val_loss did not improve from 0.56780
# Epoch 82/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4505 - accuracy: 0.8213 - val_loss: 0.6301 - val_accuracy: 0.7521
#
# Epoch 00082: val_loss did not improve from 0.56780
# Epoch 83/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4425 - accuracy: 0.8224 - val_loss: 0.5779 - val_accuracy: 0.7768
#
# Epoch 00083: val_loss did not improve from 0.56780
# Epoch 84/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4345 - accuracy: 0.8231 - val_loss: 0.6028 - val_accuracy: 0.7625
#
# Epoch 00084: val_loss did not improve from 0.56780
# Epoch 85/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4393 - accuracy: 0.8188 - val_loss: 0.5721 - val_accuracy: 0.7755
#
# Epoch 00085: val_loss did not improve from 0.56780
# Epoch 86/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4323 - accuracy: 0.8282 - val_loss: 0.5755 - val_accuracy: 0.7788
#
# Epoch 00086: val_loss did not improve from 0.56780
# Epoch 00086: early stopping
# array([[9.99635696e-01, 3.07287814e-06, 4.70106625e-06, ...,
#         3.43518547e-09, 5.88872786e-20, 3.17998805e-15],
#        [9.99999762e-01, 2.95830290e-07, 5.87719909e-14, ...,
#         7.96156919e-16, 1.03534096e-26, 1.44931000e-19],
#        [9.99996662e-01, 2.63123065e-11, 9.05954664e-07, ...,
#         3.79476184e-09, 3.76655132e-32, 4.78582663e-23],
#        ...,
#        [1.23137342e-25, 1.22624421e-19, 1.59125221e-07, ...,
#         4.06096660e-04, 1.57646857e-36, 2.71648356e-29],
#        [1.20611296e-17, 1.57218574e-06, 6.63652360e-01, ...,
#         2.02956989e-01, 1.16875006e-18, 1.84397717e-14],
#        [0.00000000e+00, 8.07237003e-12, 1.32999504e-02, ...,
#         9.02902722e-01, 5.71904435e-25, 1.80629924e-22]], dtype=float32)

# %%
del model
model = make_my_model_multi([100, 100, 100, 100], 6, 18, activation_='relu' )
model.summary()
y_pred = compile_fit_multiclass(model, X_train, X_test, y_train, 256, 200, verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 100)               700
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_8 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_9 (Dense)              (None, 18)                1818
# =================================================================
# Total params: 32,818
# Trainable params: 32,818
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 1s 4ms/step - loss: 2.4613 - accuracy: 0.1985 - val_loss: 1.8900 - val_accuracy: 0.3399
#
# Epoch 00001: val_loss did not improve from 0.56780
# Epoch 2/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.7749 - accuracy: 0.3553 - val_loss: 1.5475 - val_accuracy: 0.4270
#
# Epoch 00002: val_loss did not improve from 0.56780
# Epoch 3/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.4899 - accuracy: 0.4421 - val_loss: 1.4054 - val_accuracy: 0.4705
#
# Epoch 00003: val_loss did not improve from 0.56780
# Epoch 4/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.3773 - accuracy: 0.4750 - val_loss: 1.3133 - val_accuracy: 0.5030
#
# Epoch 00004: val_loss did not improve from 0.56780
# Epoch 5/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.3009 - accuracy: 0.5037 - val_loss: 1.2719 - val_accuracy: 0.5106
#
# Epoch 00005: val_loss did not improve from 0.56780
# Epoch 6/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.2500 - accuracy: 0.5131 - val_loss: 1.2410 - val_accuracy: 0.5099
#
# Epoch 00006: val_loss did not improve from 0.56780
# Epoch 7/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.2301 - accuracy: 0.5148 - val_loss: 1.1910 - val_accuracy: 0.5231
#
# Epoch 00007: val_loss did not improve from 0.56780
# Epoch 8/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.1699 - accuracy: 0.5409 - val_loss: 1.1618 - val_accuracy: 0.5369
#
# Epoch 00008: val_loss did not improve from 0.56780
# Epoch 9/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.1367 - accuracy: 0.5503 - val_loss: 1.1322 - val_accuracy: 0.5500
#
# Epoch 00009: val_loss did not improve from 0.56780
# Epoch 10/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.1199 - accuracy: 0.5476 - val_loss: 1.1207 - val_accuracy: 0.5525
#
# Epoch 00010: val_loss did not improve from 0.56780
# Epoch 11/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.0903 - accuracy: 0.5602 - val_loss: 1.0941 - val_accuracy: 0.5636
#
# Epoch 00011: val_loss did not improve from 0.56780
# Epoch 12/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.0618 - accuracy: 0.5717 - val_loss: 1.0688 - val_accuracy: 0.5625
#
# Epoch 00012: val_loss did not improve from 0.56780
# Epoch 13/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.0358 - accuracy: 0.5762 - val_loss: 1.0362 - val_accuracy: 0.5808
#
# Epoch 00013: val_loss did not improve from 0.56780
# Epoch 14/200
# 71/71 [==============================] - 0s 2ms/step - loss: 1.0171 - accuracy: 0.5844 - val_loss: 1.0036 - val_accuracy: 0.5930
#
# Epoch 00014: val_loss did not improve from 0.56780
# Epoch 15/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.9826 - accuracy: 0.5975 - val_loss: 0.9816 - val_accuracy: 0.6048
#
# Epoch 00015: val_loss did not improve from 0.56780
# Epoch 16/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.9739 - accuracy: 0.6050 - val_loss: 0.9693 - val_accuracy: 0.6113
#
# Epoch 00016: val_loss did not improve from 0.56780
# Epoch 17/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.9469 - accuracy: 0.6154 - val_loss: 0.9432 - val_accuracy: 0.6164
#
# Epoch 00017: val_loss did not improve from 0.56780
# Epoch 18/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.9212 - accuracy: 0.6235 - val_loss: 0.9481 - val_accuracy: 0.6148
#
# Epoch 00018: val_loss did not improve from 0.56780
# Epoch 19/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.9096 - accuracy: 0.6271 - val_loss: 0.9373 - val_accuracy: 0.6188
#
# Epoch 00019: val_loss did not improve from 0.56780
# Epoch 20/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.8925 - accuracy: 0.6341 - val_loss: 0.9123 - val_accuracy: 0.6251
#
# Epoch 00020: val_loss did not improve from 0.56780
# Epoch 21/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.8760 - accuracy: 0.6439 - val_loss: 0.9157 - val_accuracy: 0.6157
#
# Epoch 00021: val_loss did not improve from 0.56780
# Epoch 22/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.8506 - accuracy: 0.6501 - val_loss: 0.8900 - val_accuracy: 0.6440
#
# Epoch 00022: val_loss did not improve from 0.56780
# Epoch 23/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.8367 - accuracy: 0.6562 - val_loss: 0.9166 - val_accuracy: 0.6200
#
# Epoch 00023: val_loss did not improve from 0.56780
# Epoch 24/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.8267 - accuracy: 0.6614 - val_loss: 0.8566 - val_accuracy: 0.6476
#
# Epoch 00024: val_loss did not improve from 0.56780
# Epoch 25/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.8010 - accuracy: 0.6731 - val_loss: 0.8591 - val_accuracy: 0.6456
#
# Epoch 00025: val_loss did not improve from 0.56780
# Epoch 26/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7829 - accuracy: 0.6831 - val_loss: 0.8594 - val_accuracy: 0.6407
#
# Epoch 00026: val_loss did not improve from 0.56780
# Epoch 27/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7845 - accuracy: 0.6745 - val_loss: 0.8306 - val_accuracy: 0.6554
#
# Epoch 00027: val_loss did not improve from 0.56780
# Epoch 28/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7624 - accuracy: 0.6864 - val_loss: 0.7869 - val_accuracy: 0.6808
#
# Epoch 00028: val_loss did not improve from 0.56780
# Epoch 29/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7537 - accuracy: 0.6918 - val_loss: 0.8198 - val_accuracy: 0.6681
#
# Epoch 00029: val_loss did not improve from 0.56780
# Epoch 30/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7305 - accuracy: 0.6967 - val_loss: 0.7913 - val_accuracy: 0.6732
#
# Epoch 00030: val_loss did not improve from 0.56780
# Epoch 31/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7397 - accuracy: 0.6973 - val_loss: 0.7763 - val_accuracy: 0.6883
#
# Epoch 00031: val_loss did not improve from 0.56780
# Epoch 32/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7147 - accuracy: 0.7057 - val_loss: 0.8046 - val_accuracy: 0.6694
#
# Epoch 00032: val_loss did not improve from 0.56780
# Epoch 33/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7119 - accuracy: 0.7143 - val_loss: 0.8277 - val_accuracy: 0.6567
#
# Epoch 00033: val_loss did not improve from 0.56780
# Epoch 34/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7033 - accuracy: 0.7101 - val_loss: 0.7684 - val_accuracy: 0.6852
#
# Epoch 00034: val_loss did not improve from 0.56780
# Epoch 35/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.7085 - accuracy: 0.7120 - val_loss: 0.7555 - val_accuracy: 0.6924
#
# Epoch 00035: val_loss did not improve from 0.56780
# Epoch 36/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6955 - accuracy: 0.7112 - val_loss: 0.7370 - val_accuracy: 0.7037
#
# Epoch 00036: val_loss did not improve from 0.56780
# Epoch 37/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6734 - accuracy: 0.7242 - val_loss: 0.7417 - val_accuracy: 0.7031
#
# Epoch 00037: val_loss did not improve from 0.56780
# Epoch 38/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6771 - accuracy: 0.7213 - val_loss: 0.7991 - val_accuracy: 0.6732
#
# Epoch 00038: val_loss did not improve from 0.56780
# Epoch 39/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6571 - accuracy: 0.7322 - val_loss: 0.7837 - val_accuracy: 0.6799
#
# Epoch 00039: val_loss did not improve from 0.56780
# Epoch 40/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6648 - accuracy: 0.7270 - val_loss: 0.7135 - val_accuracy: 0.7135
#
# Epoch 00040: val_loss did not improve from 0.56780
# Epoch 41/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6362 - accuracy: 0.7422 - val_loss: 0.6903 - val_accuracy: 0.7189
#
# Epoch 00041: val_loss did not improve from 0.56780
# Epoch 42/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6049 - accuracy: 0.7562 - val_loss: 0.6978 - val_accuracy: 0.7129
#
# Epoch 00042: val_loss did not improve from 0.56780
# Epoch 43/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6296 - accuracy: 0.7436 - val_loss: 0.6933 - val_accuracy: 0.7195
#
# Epoch 00043: val_loss did not improve from 0.56780
# Epoch 44/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6045 - accuracy: 0.7540 - val_loss: 0.6898 - val_accuracy: 0.7291
#
# Epoch 00044: val_loss did not improve from 0.56780
# Epoch 45/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.6118 - accuracy: 0.7507 - val_loss: 0.6818 - val_accuracy: 0.7258
#
# Epoch 00045: val_loss did not improve from 0.56780
# Epoch 46/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5976 - accuracy: 0.7551 - val_loss: 0.6727 - val_accuracy: 0.7385
#
# Epoch 00046: val_loss did not improve from 0.56780
# Epoch 47/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5987 - accuracy: 0.7543 - val_loss: 0.6768 - val_accuracy: 0.7229
#
# Epoch 00047: val_loss did not improve from 0.56780
# Epoch 48/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5905 - accuracy: 0.7593 - val_loss: 0.6935 - val_accuracy: 0.7186
#
# Epoch 00048: val_loss did not improve from 0.56780
# Epoch 49/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5921 - accuracy: 0.7534 - val_loss: 0.6569 - val_accuracy: 0.7313
#
# Epoch 00049: val_loss did not improve from 0.56780
# Epoch 50/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5716 - accuracy: 0.7673 - val_loss: 0.6392 - val_accuracy: 0.7452
#
# Epoch 00050: val_loss did not improve from 0.56780
# Epoch 51/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5640 - accuracy: 0.7680 - val_loss: 0.6575 - val_accuracy: 0.7414
#
# Epoch 00051: val_loss did not improve from 0.56780
# Epoch 52/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5667 - accuracy: 0.7714 - val_loss: 0.6790 - val_accuracy: 0.7269
#
# Epoch 00052: val_loss did not improve from 0.56780
# Epoch 53/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5604 - accuracy: 0.7722 - val_loss: 0.6468 - val_accuracy: 0.7427
#
# Epoch 00053: val_loss did not improve from 0.56780
# Epoch 54/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5475 - accuracy: 0.7798 - val_loss: 0.6501 - val_accuracy: 0.7407
#
# Epoch 00054: val_loss did not improve from 0.56780
# Epoch 55/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5611 - accuracy: 0.7689 - val_loss: 0.7017 - val_accuracy: 0.7171
#
# Epoch 00055: val_loss did not improve from 0.56780
# Epoch 56/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5566 - accuracy: 0.7725 - val_loss: 0.6479 - val_accuracy: 0.7414
#
# Epoch 00056: val_loss did not improve from 0.56780
# Epoch 57/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5231 - accuracy: 0.7888 - val_loss: 0.6346 - val_accuracy: 0.7407
#
# Epoch 00057: val_loss did not improve from 0.56780
# Epoch 58/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5484 - accuracy: 0.7812 - val_loss: 0.6352 - val_accuracy: 0.7425
#
# Epoch 00058: val_loss did not improve from 0.56780
# Epoch 59/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5295 - accuracy: 0.7826 - val_loss: 0.6798 - val_accuracy: 0.7322
#
# Epoch 00059: val_loss did not improve from 0.56780
# Epoch 60/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5350 - accuracy: 0.7843 - val_loss: 0.6137 - val_accuracy: 0.7530
#
# Epoch 00060: val_loss did not improve from 0.56780
# Epoch 61/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5060 - accuracy: 0.7970 - val_loss: 0.6486 - val_accuracy: 0.7371
#
# Epoch 00061: val_loss did not improve from 0.56780
# Epoch 62/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.7766 - val_loss: 0.6275 - val_accuracy: 0.7465
#
# Epoch 00062: val_loss did not improve from 0.56780
# Epoch 63/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.5241 - accuracy: 0.7840 - val_loss: 0.6369 - val_accuracy: 0.7476
#
# Epoch 00063: val_loss did not improve from 0.56780
# Epoch 64/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.5197 - accuracy: 0.7895 - val_loss: 0.6419 - val_accuracy: 0.7447
#
# Epoch 00064: val_loss did not improve from 0.56780
# Epoch 65/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4950 - accuracy: 0.7977 - val_loss: 0.6155 - val_accuracy: 0.7530
#
# Epoch 00065: val_loss did not improve from 0.56780
# Epoch 66/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4915 - accuracy: 0.8007 - val_loss: 0.6083 - val_accuracy: 0.7576
#
# Epoch 00066: val_loss did not improve from 0.56780
# Epoch 67/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4997 - accuracy: 0.7997 - val_loss: 0.6685 - val_accuracy: 0.7340
#
# Epoch 00067: val_loss did not improve from 0.56780
# Epoch 68/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.5082 - accuracy: 0.7952 - val_loss: 0.5949 - val_accuracy: 0.7717
#
# Epoch 00068: val_loss did not improve from 0.56780
# Epoch 69/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4807 - accuracy: 0.8070 - val_loss: 0.6316 - val_accuracy: 0.7514
#
# Epoch 00069: val_loss did not improve from 0.56780
# Epoch 70/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4942 - accuracy: 0.8002 - val_loss: 0.6300 - val_accuracy: 0.7483
#
# Epoch 00070: val_loss did not improve from 0.56780
# Epoch 71/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4851 - accuracy: 0.8008 - val_loss: 0.5889 - val_accuracy: 0.7703
#
# Epoch 00071: val_loss did not improve from 0.56780
# Epoch 72/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4674 - accuracy: 0.8178 - val_loss: 0.5917 - val_accuracy: 0.7623
#
# Epoch 00072: val_loss did not improve from 0.56780
# Epoch 73/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4490 - accuracy: 0.8200 - val_loss: 0.6155 - val_accuracy: 0.7505
#
# Epoch 00073: val_loss did not improve from 0.56780
# Epoch 74/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4727 - accuracy: 0.8065 - val_loss: 0.6075 - val_accuracy: 0.7603
#
# Epoch 00074: val_loss did not improve from 0.56780
# Epoch 75/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4610 - accuracy: 0.8128 - val_loss: 0.6080 - val_accuracy: 0.7607
#
# Epoch 00075: val_loss did not improve from 0.56780
# Epoch 76/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4611 - accuracy: 0.8145 - val_loss: 0.5776 - val_accuracy: 0.7717
#
# Epoch 00076: val_loss did not improve from 0.56780
# Epoch 77/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4446 - accuracy: 0.8220 - val_loss: 0.5966 - val_accuracy: 0.7679
#
# Epoch 00077: val_loss did not improve from 0.56780
# Epoch 78/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4467 - accuracy: 0.8227 - val_loss: 0.5879 - val_accuracy: 0.7668
#
# Epoch 00078: val_loss did not improve from 0.56780
# Epoch 79/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4483 - accuracy: 0.8152 - val_loss: 0.6033 - val_accuracy: 0.7619
#
# Epoch 00079: val_loss did not improve from 0.56780
# Epoch 80/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4518 - accuracy: 0.8143 - val_loss: 0.5813 - val_accuracy: 0.7643
#
# Epoch 00080: val_loss did not improve from 0.56780
# Epoch 81/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4437 - accuracy: 0.8230 - val_loss: 0.6511 - val_accuracy: 0.7429
#
# Epoch 00081: val_loss did not improve from 0.56780
# Epoch 82/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4497 - accuracy: 0.8215 - val_loss: 0.6188 - val_accuracy: 0.7561
#
# Epoch 00082: val_loss did not improve from 0.56780
# Epoch 83/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4241 - accuracy: 0.8289 - val_loss: 0.5720 - val_accuracy: 0.7714
#
# Epoch 00083: val_loss did not improve from 0.56780
# Epoch 84/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4268 - accuracy: 0.8287 - val_loss: 0.5718 - val_accuracy: 0.7694
#
# Epoch 00084: val_loss did not improve from 0.56780
# Epoch 85/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4314 - accuracy: 0.8260 - val_loss: 0.6417 - val_accuracy: 0.7458
#
# Epoch 00085: val_loss did not improve from 0.56780
# Epoch 86/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4392 - accuracy: 0.8196 - val_loss: 0.5803 - val_accuracy: 0.7645
#
# Epoch 00086: val_loss did not improve from 0.56780
# Epoch 87/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4512 - accuracy: 0.8180 - val_loss: 0.5790 - val_accuracy: 0.7728
#
# Epoch 00087: val_loss did not improve from 0.56780
# Epoch 88/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4230 - accuracy: 0.8312 - val_loss: 0.5704 - val_accuracy: 0.7775
#
# Epoch 00088: val_loss did not improve from 0.56780
# Epoch 89/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4207 - accuracy: 0.8343 - val_loss: 0.5873 - val_accuracy: 0.7668
#
# Epoch 00089: val_loss did not improve from 0.56780
# Epoch 90/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4109 - accuracy: 0.8361 - val_loss: 0.5746 - val_accuracy: 0.7783
#
# Epoch 00090: val_loss did not improve from 0.56780
# Epoch 91/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4143 - accuracy: 0.8321 - val_loss: 0.5685 - val_accuracy: 0.7761
#
# Epoch 00091: val_loss did not improve from 0.56780
# Epoch 92/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4103 - accuracy: 0.8355 - val_loss: 0.5702 - val_accuracy: 0.7783
#
# Epoch 00092: val_loss did not improve from 0.56780
# Epoch 93/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4123 - accuracy: 0.8360 - val_loss: 0.5832 - val_accuracy: 0.7690
#
# Epoch 00093: val_loss did not improve from 0.56780
# Epoch 94/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4107 - accuracy: 0.8305 - val_loss: 0.6064 - val_accuracy: 0.7632
#
# Epoch 00094: val_loss did not improve from 0.56780
# Epoch 95/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4192 - accuracy: 0.8329 - val_loss: 0.5842 - val_accuracy: 0.7650
#
# Epoch 00095: val_loss did not improve from 0.56780
# Epoch 96/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4064 - accuracy: 0.8385 - val_loss: 0.6478 - val_accuracy: 0.7460
#
# Epoch 00096: val_loss did not improve from 0.56780
# Epoch 97/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.4233 - accuracy: 0.8267 - val_loss: 0.5847 - val_accuracy: 0.7766
#
# Epoch 00097: val_loss did not improve from 0.56780
# Epoch 98/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3874 - accuracy: 0.8453 - val_loss: 0.6010 - val_accuracy: 0.7614
#
# Epoch 00098: val_loss did not improve from 0.56780
# Epoch 99/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3941 - accuracy: 0.8430 - val_loss: 0.6480 - val_accuracy: 0.7530
#
# Epoch 00099: val_loss did not improve from 0.56780
# Epoch 100/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4123 - accuracy: 0.8316 - val_loss: 0.6077 - val_accuracy: 0.7599
#
# Epoch 00100: val_loss did not improve from 0.56780
# Epoch 101/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3903 - accuracy: 0.8426 - val_loss: 0.5738 - val_accuracy: 0.7812
#
# Epoch 00101: val_loss did not improve from 0.56780
# Epoch 00101: early stopping

# %%
#PRUEBA
y_pred = compile_fit_multiclass(model, X_train, X_test, y_train, 256, 200, verbose=1)

# %%
from sklearn.metrics import confusion_matrix, precision_score, \
f1_score, cohen_kappa_score, recall_score

# %%
confusion = confusion_matrix(np.argmax(y_pred, axis = 1), np.argmax(y_test, axis = 1))
print(confusion)

# %%
compute_metrics_multiclass(np.argmax(y_pred, axis = 1), np.argmax(y_test, axis = 1))

# %%
import imblearn
from collections import Counter

# %%
counter = Counter(y)
for k,v in counter.items():
	per = v / len(y) * 100
	print('Class=%d, n=%d (%.3f%%)' % (k, v, per))

# %%
X_train.shape, np.argmax(y_train, axis=1).shape

# %%
X_train_smote.shape, y_train_smote.shape

# %%
X_train.shape, X_train_smote.shape, y_train.shape, y_train_smote.shape, X_test.shape, y_test.shape

# %%
np.random.seed(seed)
model = make_my_model_multi([100, 100, 100, 100], 6, 18, activation_='relu' )
model.summary()

# %%
#tf.random.set_seed(seed)
model.summary()
y_pred = compile_fit_multiclass(model, X_train, X_test, y_train, 256, 200, verbose=1)

# %%
confusion = confusion_matrix(np.argmax(y_pred, axis = 1), np.argmax(y_test, axis = 1))
print(confusion)

# %%
compute_metrics_multiclass(np.argmax(y_pred, axis = 1), np.argmax(y_test, axis = 1))

# %%
np.argmax(y_pred, axis=1)

# %%
#model.save("de_momento_mejor.h5")

# %% [markdown]
# # SMOTE NO VA BIEN

# %% [markdown]
# # Seguimos probando con con dropout

# %%
from tensorflow.keras.layers import Dropout

def make_my_model_multi_dropout( units_per_layer, input_s, output_s, activation_='relu', dropout_r=0.2):
    model = Sequential()
    depth = len(units_per_layer)
    model.add(Dense(units_per_layer[0], activation=activation_, input_shape=(input_s,)))
    for i in range(1, depth):
        model.add(Dropout(dropout_r))
        model.add(Dense(units_per_layer[i], activation=activation_))
    model.add(Dense(output_s, activation = 'softmax'))   
    
    return model

# %%
seed = 1
np.random.seed(seed)
model = make_my_model_multi_dropout([100, 100, 100, 100, 100, 100, 100], 6, 18, activation_='relu', dropout_r=0.2)
model.summary()
tf.random.set_seed(
    seed
)

# %%
y_pred_dropout = compile_fit_multiclass(model, X_train, X_test, y_train, 256, 100, verbose=1)

# %%
compute_metrics_multiclass(np.argmax(y_pred_dropout, axis = 1), np.argmax(y_test, axis = 1))

# %%
confusion = confusion_matrix(np.argmax(y_pred_dropout, axis = 1), np.argmax(y_test, axis = 1))
print(confusion)

# %%
y_pred_smote_dropout

# %% [markdown]
# About
#
# If you use imbalanced-learn in a scientific publication, we would appreciate citations to the following paper:
#
# @article{JMLR:v18:16-365,
# author  = {Guillaume  Lema{{\^i}}tre and Fernando Nogueira and Christos K. Aridas},
# title   = {Imbalanced-learn: A Python Toolbox to Tackle the Curse of Imbalanced Datasets in Machine Learning},
# journal = {Journal of Machine Learning Research},
# year    = {2017},
# volume  = {18},
# number  = {17},
# pages   = {1-5},
# url     = {http://jmlr.org/papers/v18/16-365}
# }
#
# Most classification algorithms will only perform optimally when the number of samples of each class is roughly the same. Highly skewed datasets, where the minority is heavily outnumbered by one or more classes, have proven to be a challenge while at the same time becoming more and more common.
#
# One way of addressing this issue is by re-sampling the dataset as to offset this imbalance with the hope of arriving at a more robust and fair decision boundary than you would otherwise.

# %%
import tensorflow as tf
tf.version.VERSION
